# %% [markdown]
# ## The Sparks Foundation
# ### Data Science and Business Analytics (GRIP SEPTEMBER'21)

# %% [markdown]
# #### # Task 6
# #### Author: Chiranjeev Sehgal
# #### Task Title: Prediction using Decision Tree Algorithm
# #### Problem Statement: The classifier should predict the right class whenever we feed any new data to it.
# #### Dataset Provided: https://bit.ly/3kXTdox

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading the dataset

# %%
data=pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### To convert labels into numerical form

# %%
species_le = LabelEncoder()
data['Species_n'] = species_le.fit_transform(data['Species'])

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Species_n
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# #### On comparing the columns, following are the encoded vaues:
# #### 0 - Iris-setosa
# #### 1 - Iris-versicolor
# #### 2 - Iris-virginica

# %% [markdown]
# ### Splitting features and labels

# %%
features = data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
target = data['Species_n']

# %%
features.shape
# Out:
# (150, 4)

# %%
target.shape
# Out:
# (150,)

# %% [markdown]
# ### Train_Test_Split Data

# %%
x_train, x_test, y_train, y_test = train_test_split(features,target, test_size=0.3)

# %% [markdown]
# ### Defining the decision tree algorithm

# %%
model = tree.DecisionTreeClassifier()
model.fit(x_train,y_train)
print("Decision Tree Classifer Created")
# Out:
# Decision Tree Classifer Created

# %% [markdown]
# ### Checking the model score on test data

# %%
print("The score is :",model.score(x_test,y_test))
# Out:
# The score is : 0.9777777777777777

# %% [markdown]
# ### Preparing feature names and class name for Data Visualization

# %%
f_name = list(features.columns)
t_name =list(data.Species.unique())

# %% [markdown]
# ### Visualizing the Decision Tree to understand it better.

# %%
plt.figure(figsize=(25,12))
plttree = tree.plot_tree(model, feature_names=f_name, class_names=t_name, filled=True)

# %% [markdown]
# ### Now if we feed any data to the Decision Tree Classifier, the model would be able to predict the right class accordingly.
